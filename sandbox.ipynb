# %%
import pandas as pd

# %%
accident_df = pd.read_csv("datasets/accident.csv")
person_df = pd.read_csv("datasets/person.csv")
filtered_vehicle_df = pd.read_csv("datasets/filtered_vehicle.csv")
vehicle_df = pd.read_csv("datasets/vehicle.csv")

# %%
accident_df["SEVERITY"].value_counts()
# Out:
# SEVERITY
# 3    111382
# 2     64365
# 1      2944
# 4         4
# Name: count, dtype: int64

# %%
accident_df[accident_df["SEVERITY"] == 4]
# Out:
#          ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  ACCIDENT_TYPE  \
# 114000  T20190025836    2019-12-20      16:30:00              1
# 130725  T20210007571    2021-04-05      10:00:00              1
# 145312  T20220009177    2022-04-24      22:16:00              1
# 153550  T20220025610    2022-11-13      07:00:00              8
#
#                        ACCIDENT_TYPE_DESC  DAY_OF_WEEK DAY_WEEK_DESC  \
# 114000             Collision with vehicle            5        Friday
# 130725             Collision with vehicle            1        Monday
# 145312             Collision with vehicle            0        Sunday
# 153550  No collision and no object struck            0        Sunday
#
#         DCA_CODE                                           DCA_DESC  \
# 114000       129  OTHER OPPOSING MANOEUVRES NOT INCLUDED IN DCAs...
# 130725       130                    REAR END(VEHICLES IN SAME LANE)
# 145312       137                                LEFT TURN SIDESWIPE
# 153550       179  OTHER ACCIDENTS-OFF STRAIGHT NOT INCLUDED IN D...
#
#         LIGHT_CONDITION  ...  NO_PERSONS_INJ_2  NO_PERSONS_INJ_3  \
# 114000                1  ...                 0                 0
# 130725                1  ...                 0                 0
# 145312                3  ...                 0                 0
# 153550                1  ...                 0                 0
#
#         NO_PERSONS_NOT_INJ  NO_PERSONS  POLICE_ATTEND  ROAD_GEOMETRY  \
# 114000                   2           2              1              5
# 130725                   2           2              2              2
# 145312                   2           2              1              1
# 153550                   1           1              1              1
#
#          ROAD_GEOMETRY_DESC  SEVERITY  SPEED_ZONE             RMA
# 114000  Not at intersection         4         100             NaN
# 130725       T intersection         4          40  Arterial Other
# 145312   Cross intersection         4          40      Local Road
# 153550   Cross intersection         4         999      Local Road
#
# [4 rows x 23 columns]
